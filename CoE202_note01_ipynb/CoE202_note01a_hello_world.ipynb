# %% [markdown]
# # [CoE202] note 01a. Hello World
#
# - Class Date : 2021.03.11.
# - Office Hour : TBA
# - If you have any questions, upload on KLMS Q&A board, or ask directly at the TA office hours (Zoom).

# %% [markdown]
# ## 1. Print text
# Let's try runing the simplest code in the world, aka 'hello world'!

# %%
# annotation 
print('Hello world')
# Out:
# Hello world
